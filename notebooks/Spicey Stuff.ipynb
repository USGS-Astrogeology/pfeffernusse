# %%
# from plio.io.io_gdal import GeoDataset 
import pvl
from glob import glob 
import spiceypy as spice
import requests
import os 
import json

# %%
lroc_label = """
PDS_VERSION_ID                     = PDS3

/*FILE CHARACTERISTICS*/
RECORD_TYPE                        = FIXED_LENGTH
RECORD_BYTES                       = 5064      
FILE_RECORDS                       = 13313     
LABEL_RECORDS                      = 1         
^IMAGE                             = 2         

/*DATA IDENTIFICATION*/
DATA_SET_ID                        = "LRO-L-LROC-2-EDR-V1.0"
ORIGINAL_PRODUCT_ID                = nacl0002fc60
PRODUCT_ID                         = M128963531LE
MISSION_NAME                       = "LUNAR RECONNAISSANCE ORBITER"
MISSION_PHASE_NAME                 = "NOMINAL MISSION"
INSTRUMENT_HOST_NAME               = "LUNAR RECONNAISSANCE ORBITER"
INSTRUMENT_HOST_ID                 = LRO
INSTRUMENT_NAME                    = "LUNAR RECONNAISSANCE ORBITER CAMERA"
INSTRUMENT_ID                      = LROC
LRO:PREROLL_TIME                   = 2010-05-20T02:57:44.373
START_TIME                         = 2010-05-20T02:57:44.720
STOP_TIME                          = 2010-05-20T02:57:49.235
LRO:SPACECRAFT_CLOCK_PREROLL_COUNT = "1/296017064:22937"
SPACECRAFT_CLOCK_START_COUNT       = "1/296017064:45694"
SPACECRAFT_CLOCK_STOP_COUNT        = "1/296017069:13866"
ORBIT_NUMBER                       = 4138
PRODUCER_ID                        = LRO_LROC_TEAM
PRODUCT_CREATION_TIME              = 2013-09-16T19:57:12
PRODUCER_INSTITUTION_NAME          = "ARIZONA STATE UNIVERSITY"
PRODUCT_TYPE                       = EDR
PRODUCT_VERSION_ID                 = "v1.8"
UPLOAD_ID                          = "SC_2010140_0000_A_V01.txt"

/*DATA DESCRIPTION*/
TARGET_NAME                        = "MOON"
RATIONALE_DESC                     = "TARGET OF OPPORTUNITY"
FRAME_ID                           = LEFT
DATA_QUALITY_ID                    = "0"
DATA_QUALITY_DESC                  = "The DATA_QUALITY_ID is set to an 8-bit
   value that encodes the following data quality information for the 
   observation. For each bit  a value of 0 means FALSE and a value of 1 means 
   TRUE. More information about the data quality ID can be found in the LROC
   EDR/CDR SIS, section 3.3 'Label and Header Descriptions'.
       Bit 1: Temperature of focal plane array is out of bounds.
       Bit 2: Threshold for saturated pixels is reached.
       Bit 3: Threshold for under-saturated pixels is reached.
       Bit 4: Observation is missing telemetry packets.
       Bit 5: SPICE information is bad or missing.
       Bit 6: Observation or housekeeping information is bad or missing.
       Bit 7: Spare.
       Bit 8: Spare."

/*ENVIRONMENT*/
LRO:TEMPERATURE_SCS                = 4.51 <degC>
LRO:TEMPERATURE_FPA                = 17.88 <degC>
LRO:TEMPERATURE_FPGA               = -12.33 <degC>
LRO:TEMPERATURE_TELESCOPE          = 5.91 <degC>
LRO:TEMPERATURE_SCS_RAW            = 2740
LRO:TEMPERATURE_FPA_RAW            = 2107
LRO:TEMPERATURE_FPGA_RAW           = 3418
LRO:TEMPERATURE_TELESCOPE_RAW      = 2675

/*IMAGING PARAMETERS*/
CROSSTRACK_SUMMING                 = 1
BANDWIDTH                          = 300 <nm>
CENTER_FILTER_WAVELENGTH           = 600 <nm>
LINE_EXPOSURE_DURATION             = 0.337600 <ms>
LRO:LINE_EXPOSURE_CODE             = 0
LRO:DAC_RESET_LEVEL                = 198
LRO:CHANNEL_A_OFFSET               = 60
LRO:CHANNEL_B_OFFSET               = 123
LRO:COMPAND_CODE                   = 3
LRO:LINE_CODE                      = 13
LRO:BTERM                          = (0,16,69,103,128)
LRO:MTERM                          = (0.5,0.25,0.125,0.0625,0.03125)
LRO:XTERM                          = (0,64,424,536,800)
LRO:COMPRESSION_FLAG               = 1
LRO:MODE                           = 7

/*DATA OBJECT*/
OBJECT                             = IMAGE
    LINES                          = 13312
    LINE_SAMPLES                   = 5064
    SAMPLE_BITS                    = 8
    SAMPLE_TYPE                    = LSB_INTEGER
    UNIT                           = "RAW_INSTRUMENT_COUNT"
    MD5_CHECKSUM                   = "0fe91f4b2e93083ee0093e7c8d05f3bc"
END_OBJECT                         = IMAGE
END
"""
label = pvl.loads(lroc_label)

# %%
r = requests.get("http://localhost:58080/v1/metalkernels/", params={'mission' : '', 'version': 'latest', 'year': ''})
r.json()
# Out:
# {'count': 58,
#  'data': [{'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/mdis_cklist_v02.tm',
#    'version': 'v02',
#    'year': 'cklist'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v13.tm',
#    'version': 'v13',
#    'year': '2004'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v13.tm',
#    'version': 'v13',
#    'year': '2005'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v13.tm',
#    'version': 'v13',
#    'year': '2006'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v13.tm',
#    'version': 'v13',
#    'year': '2007'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v12.tm',
#    'version': 'v12',
#    'year': '2008'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2009_v10.tm',
#    'version': 'v10',
#    'year': '2009'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2010_v09.tm',
#    'version': 'v09',
#    'year': '2010'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2011_v10.tm',
#    'version': 'v10',
#    'year': '2011'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2012_v08.tm',
#    'version': 'v08',
#    'year': '2012'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2013_v06.tm',
#    'version': 'v06',
#    'year': '2013'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2014_v04.tm',
#    'version': 'v04',
#    'year': '2014'},
#   {'mission': 'mess',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2015_v02.tm',
#    'version': 'v02',
#    'year': '2015'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v21.tm',
#    'version': 'v21',
#    'year': '1997'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v21.tm',
#    'version': 'v21',
#    'year': '1998'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v21.tm',
#    'version': 'v21',
#    'year': '1999'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v23.tm',
#    'version': 'v23',
#    'year': '2000'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v24.tm',
#    'version': 'v24',
#    'year': '2001'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v23.tm',
#    'version': 'v23',
#    'year': '2002'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v25.tm',
#    'version': 'v25',
#    'year': '2003'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v25.tm',
#    'version': 'v25',
#    'year': '2004'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v26.tm',
#    'version': 'v26',
#    'year': '2005'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2006_v25.tm',
#    'version': 'v25',
#    'year': '2006'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v23.tm',
#    'version': 'v23',
#    'year': '2007'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v21.tm',
#    'version': 'v21',
#    'year': '2008'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v18.tm',
#    'version': 'v18',
#    'year': '2009'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v17.tm',
#    'version': 'v17',
#    'year': '2010'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2011_v16.tm',
#    'version': 'v16',
#    'year': '2011'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v13.tm',
#    'version': 'v13',
#    'year': '2012'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v11.tm',
#    'version': 'v11',
#    'year': '2013'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2014_v07.tm',
#    'version': 'v07',
#    'year': '2014'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2015_v07.tm',
#    'version': 'v07',
#    'year': '2015'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2016_v05.tm',
#    'version': 'v05',
#    'year': '2016'},
#   {'mission': 'co',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2017_v02.tm',
#    'version': 'v02',
#    'year': '2017'},
#   {'mission': 'lro',
#    'path': '/data/spice/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/lro_2009_v04.tm',
#    'version': 'v04',
#    'year': '2009'},
#   {'mission': 'lro',
#    'path': '/data/spice/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/lro_2010_v07.tm',
#    'version': 'v07',
#    'year': '2010'},
#   {'mission': 'lro',
#    'path': '/data/spice/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/lro_2011_v08.tm',
#    'version': 'v08',
#    'year': '2011'},
#   {'mission': 'lro',
#    'path': '/data/spice/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/lro_2012_v09.tm',
#    'version': 'v09',
#    'year': '2012'},
#   {'mission': 'lro',
#    'path': '/data/spice/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/lro_2013_v08.tm',
#    'version': 'v08',
#    'year': '2013'},
#   {'mission': 'lro',
#    'path': '/data/spice/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/lro_2014_v08.tm',
#    'version': 'v08',
#    'year': '2014'},
#   {'mission': 'lro',
#    'path': '/data/spice/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/lro_2015_v06.tm',
#    'version': 'v06',
#    'year': '2015'},
#   {'mission': 'lro',
#    'path': '/data/spice/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/lro_2016_v05.tm',
#    'version': 'v05',
#    'year': '2016'},
#   {'mission': 'lro',
#    'path': '/data/spice/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/lro_2017_v05.tm',
#    'version': 'v05',
#    'year': '2017'},
#   {'mission': 'lro',
#    'path': '/data/spice/lro-l-spice-6-v1.0/lrosp_1000/extras/mk/lro_2018_v02.tm',
#    'version': 'v02',
#    'year': '2018'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2005_v08.tm',
#    'version': 'v08',
#    'year': '2005'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2006_v10.tm',
#    'version': 'v10',
#    'year': '2006'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v12.tm',
#    'version': 'v12',
#    'year': '2007'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v11.tm',
#    'version': 'v11',
#    'year': '2008'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v11.tm',
#    'version': 'v11',
#    'year': '2009'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v13.tm',
#    'version': 'v13',
#    'year': '2010'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2011_v10.tm',
#    'version': 'v10',
#    'year': '2011'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2012_v09.tm',
#    'version': 'v09',
#    'year': '2012'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2013_v09.tm',
#    'version': 'v09',
#    'year': '2013'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2014_v07.tm',
#    'version': 'v07',
#    'year': '2014'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2015_v05.tm',
#    'version': 'v05',
#    'year': '2015'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2016_v05.tm',
#    'version': 'v05',
#    'year': '2016'},
#   {'mission': 'mro',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2017_v03.tm',
#    'version': 'v03',
#    'year': '2017'},
#   {'mission': 'apollo.sese.asu.edu',
#    'version': '/data/spice/apollo.sese.asu.edu/EPHEMERIS/kernels/AS15/extras/mk/apollo15_v01.tm',
#    'year': 'v01'}]}

# %%
r = requests.post("http://localhost:58080/v1/pds/", json={'label' : lroc_label})

# %%
from pfeffernusse import util
util.get_metakernels(years="")
# Out:
# {'count': 664,
#  'data': [{'mission': 'mess',
#    'year': 'cklist',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/mdis_cklist_v02.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v01.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v02.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v03',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v03.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v04',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v04.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v05',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v05.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v06',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v06.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v07',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v07.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v08',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v08.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v09',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v09.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v10',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v10.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v11',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v11.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v12',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v12.tm'},
#   {'mission': 'mess',
#    'year': '2004',
#    'version': 'v13',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2004_v13.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v01.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v02.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v03',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v03.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v04',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v04.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v05',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v05.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v06',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v06.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v07',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v07.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v08',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v08.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v09',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v09.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v10',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v10.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v11',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v11.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v12',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v12.tm'},
#   {'mission': 'mess',
#    'year': '2005',
#    'version': 'v13',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2005_v13.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v01.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v02.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v03',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v03.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v04',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v04.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v05',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v05.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v06',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v06.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v07',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v07.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v08',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v08.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v09',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v09.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v10',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v10.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v11',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v11.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v12',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v12.tm'},
#   {'mission': 'mess',
#    'year': '2006',
#    'version': 'v13',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2006_v13.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v01.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v02.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v03',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v03.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v04',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v04.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v05',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v05.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v06',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v06.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v07',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v07.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v08',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v08.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v09',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v09.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v10',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v10.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v11',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v11.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v12',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v12.tm'},
#   {'mission': 'mess',
#    'year': '2007',
#    'version': 'v13',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2007_v13.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v01.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v02.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v03',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v03.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v04',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v04.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v05',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v05.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v06',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v06.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v07',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v07.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v08',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v08.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v09',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v09.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v10',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v10.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v11',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v11.tm'},
#   {'mission': 'mess',
#    'year': '2008',
#    'version': 'v12',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2008_v12.tm'},
#   {'mission': 'mess',
#    'year': '2009',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2009_v01.tm'},
#   {'mission': 'mess',
#    'year': '2009',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2009_v02.tm'},
#   {'mission': 'mess',
#    'year': '2009',
#    'version': 'v03',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2009_v03.tm'},
#   {'mission': 'mess',
#    'year': '2009',
#    'version': 'v04',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2009_v04.tm'},
#   {'mission': 'mess',
#    'year': '2009',
#    'version': 'v05',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2009_v05.tm'},
#   {'mission': 'mess',
#    'year': '2009',
#    'version': 'v06',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2009_v06.tm'},
#   {'mission': 'mess',
#    'year': '2009',
#    'version': 'v07',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2009_v07.tm'},
#   {'mission': 'mess',
#    'year': '2009',
#    'version': 'v08',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2009_v08.tm'},
#   {'mission': 'mess',
#    'year': '2009',
#    'version': 'v09',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2009_v09.tm'},
#   {'mission': 'mess',
#    'year': '2009',
#    'version': 'v10',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2009_v10.tm'},
#   {'mission': 'mess',
#    'year': '2010',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2010_v01.tm'},
#   {'mission': 'mess',
#    'year': '2010',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2010_v02.tm'},
#   {'mission': 'mess',
#    'year': '2010',
#    'version': 'v03',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2010_v03.tm'},
#   {'mission': 'mess',
#    'year': '2010',
#    'version': 'v04',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2010_v04.tm'},
#   {'mission': 'mess',
#    'year': '2010',
#    'version': 'v05',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2010_v05.tm'},
#   {'mission': 'mess',
#    'year': '2010',
#    'version': 'v06',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2010_v06.tm'},
#   {'mission': 'mess',
#    'year': '2010',
#    'version': 'v07',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2010_v07.tm'},
#   {'mission': 'mess',
#    'year': '2010',
#    'version': 'v08',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2010_v08.tm'},
#   {'mission': 'mess',
#    'year': '2010',
#    'version': 'v09',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2010_v09.tm'},
#   {'mission': 'mess',
#    'year': '2011',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2011_v01.tm'},
#   {'mission': 'mess',
#    'year': '2011',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2011_v02.tm'},
#   {'mission': 'mess',
#    'year': '2011',
#    'version': 'v03',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2011_v03.tm'},
#   {'mission': 'mess',
#    'year': '2011',
#    'version': 'v04',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2011_v04.tm'},
#   {'mission': 'mess',
#    'year': '2011',
#    'version': 'v05',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2011_v05.tm'},
#   {'mission': 'mess',
#    'year': '2011',
#    'version': 'v06',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2011_v06.tm'},
#   {'mission': 'mess',
#    'year': '2011',
#    'version': 'v07',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2011_v07.tm'},
#   {'mission': 'mess',
#    'year': '2011',
#    'version': 'v08',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2011_v08.tm'},
#   {'mission': 'mess',
#    'year': '2011',
#    'version': 'v09',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2011_v09.tm'},
#   {'mission': 'mess',
#    'year': '2011',
#    'version': 'v10',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2011_v10.tm'},
#   {'mission': 'mess',
#    'year': '2012',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2012_v01.tm'},
#   {'mission': 'mess',
#    'year': '2012',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2012_v02.tm'},
#   {'mission': 'mess',
#    'year': '2012',
#    'version': 'v03',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2012_v03.tm'},
#   {'mission': 'mess',
#    'year': '2012',
#    'version': 'v04',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2012_v04.tm'},
#   {'mission': 'mess',
#    'year': '2012',
#    'version': 'v05',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2012_v05.tm'},
#   {'mission': 'mess',
#    'year': '2012',
#    'version': 'v06',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2012_v06.tm'},
#   {'mission': 'mess',
#    'year': '2012',
#    'version': 'v07',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2012_v07.tm'},
#   {'mission': 'mess',
#    'year': '2012',
#    'version': 'v08',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2012_v08.tm'},
#   {'mission': 'mess',
#    'year': '2013',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2013_v01.tm'},
#   {'mission': 'mess',
#    'year': '2013',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2013_v02.tm'},
#   {'mission': 'mess',
#    'year': '2013',
#    'version': 'v03',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2013_v03.tm'},
#   {'mission': 'mess',
#    'year': '2013',
#    'version': 'v04',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2013_v04.tm'},
#   {'mission': 'mess',
#    'year': '2013',
#    'version': 'v05',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2013_v05.tm'},
#   {'mission': 'mess',
#    'year': '2013',
#    'version': 'v06',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2013_v06.tm'},
#   {'mission': 'mess',
#    'year': '2014',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2014_v01.tm'},
#   {'mission': 'mess',
#    'year': '2014',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2014_v02.tm'},
#   {'mission': 'mess',
#    'year': '2014',
#    'version': 'v03',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2014_v03.tm'},
#   {'mission': 'mess',
#    'year': '2014',
#    'version': 'v04',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2014_v04.tm'},
#   {'mission': 'mess',
#    'year': '2015',
#    'version': 'v01',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2015_v01.tm'},
#   {'mission': 'mess',
#    'year': '2015',
#    'version': 'v02',
#    'path': '/data/spice/mess-e_v_h-spice-6-v1.0/messsp_1000/extras/mk/msgr_2015_v02.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v01',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v01.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v02',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v02.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v03',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v03.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v04',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v04.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v05',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v05.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v06',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v06.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v07',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v07.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v08',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v08.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v09',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v09.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v10',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v10.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v11',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v11.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v12',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v12.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v13',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v13.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v14',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v14.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v15',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v15.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v16',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v16.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v17',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v17.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v18',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v18.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v19',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v19.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v20',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v20.tm'},
#   {'mission': 'co',
#    'year': '1997',
#    'version': 'v21',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v21.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v01',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v01.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v02',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v02.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v03',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v03.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v04',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v04.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v05',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v05.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v06',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v06.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v07',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v07.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v08',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v08.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v09',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v09.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v10',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v10.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v11',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v11.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v12',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v12.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v13',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v13.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v14',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v14.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v15',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v15.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v16',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v16.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v17',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v17.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v18',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v18.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v19',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v19.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v20',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v20.tm'},
#   {'mission': 'co',
#    'year': '1998',
#    'version': 'v21',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v21.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v01',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v01.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v02',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v02.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v03',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v03.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v04',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v04.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v05',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v05.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v06',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v06.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v07',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v07.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v08',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v08.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v09',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v09.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v10',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v10.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v11',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v11.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v12',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v12.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v13',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v13.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v14',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v14.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v15',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v15.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v16',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v16.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v17',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v17.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v18',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v18.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v19',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v19.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v20',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v20.tm'},
#   {'mission': 'co',
#    'year': '1999',
#    'version': 'v21',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v21.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v01',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v01.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v02',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v02.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v03',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v03.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v04',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v04.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v05',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v05.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v06',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v06.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v07',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v07.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v08',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v08.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v09',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v09.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v10',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v10.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v11',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v11.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v12',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v12.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v13',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v13.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v14',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v14.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v15',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v15.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v16',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v16.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v17',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v17.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v18',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v18.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v19',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v19.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v20',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v20.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v21',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v21.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v22',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v22.tm'},
#   {'mission': 'co',
#    'year': '2000',
#    'version': 'v23',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v23.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v01',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v01.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v02',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v02.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v03',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v03.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v04',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v04.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v05',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v05.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v06',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v06.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v07',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v07.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v08',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v08.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v09',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v09.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v10',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v10.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v11',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v11.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v12',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v12.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v13',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v13.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v14',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v14.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v15',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v15.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v16',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v16.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v17',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v17.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v18',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v18.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v19',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v19.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v20',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v20.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v21',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v21.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v22',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v22.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v23',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v23.tm'},
#   {'mission': 'co',
#    'year': '2001',
#    'version': 'v24',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v24.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v01',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v01.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v02',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v02.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v03',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v03.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v04',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v04.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v05',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v05.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v06',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v06.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v07',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v07.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v08',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v08.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v09',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v09.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v10',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v10.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v11',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v11.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v12',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v12.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v13',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v13.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v14',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v14.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v15',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v15.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v16',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v16.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v17',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v17.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v18',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v18.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v19',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v19.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v20',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v20.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v21',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v21.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v22',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v22.tm'},
#   {'mission': 'co',
#    'year': '2002',
#    'version': 'v23',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2002_v23.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v01',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v01.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v02',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v02.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v03',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v03.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v04',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v04.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v05',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v05.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v06',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v06.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v07',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v07.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v08',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v08.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v09',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v09.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v10',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v10.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v11',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v11.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v12',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v12.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v13',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v13.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v14',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v14.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v15',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v15.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v16',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v16.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v17',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v17.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v18',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v18.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v19',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v19.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v20',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v20.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v21',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v21.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v22',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v22.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v23',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v23.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v24',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v24.tm'},
#   {'mission': 'co',
#    'year': '2003',
#    'version': 'v25',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v25.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v01',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v01.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v02',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v02.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v03',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v03.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v04',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v04.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v05',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v05.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v06',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v06.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v07',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v07.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v08',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v08.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v09',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v09.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v10',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v10.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v11',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v11.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v12',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v12.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v13',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v13.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v14',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v14.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v15',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v15.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v16',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v16.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v17',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v17.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v18',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v18.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v19',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v19.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v20',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v20.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v21',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v21.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v22',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v22.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v23',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v23.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v24',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v24.tm'},
#   {'mission': 'co',
#    'year': '2004',
#    'version': 'v25',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v25.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v01',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v01.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v02',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v02.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v03',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v03.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v04',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v04.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v05',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v05.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v06',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v06.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v07',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v07.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v08',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v08.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v09',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v09.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v10',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v10.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v11',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v11.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v12',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v12.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v13',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v13.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v14',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v14.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v15',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v15.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v16',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v16.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v17',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v17.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v18',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v18.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v19',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v19.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v20',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v20.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v21',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v21.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v22',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v22.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v23',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v23.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v24',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v24.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v25',
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v25.tm'},
#   {'mission': 'co',
#    'year': '2005',
#    'version': 'v26',
# ...
#   {'mission': 'mro',
#    'year': '2005',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2005_v04.tm'},
#   {'mission': 'mro',
#    'year': '2005',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2005_v05.tm'},
#   {'mission': 'mro',
#    'year': '2005',
#    'version': 'v06',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2005_v06.tm'},
#   {'mission': 'mro',
#    'year': '2005',
#    'version': 'v07',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2005_v07.tm'},
#   {'mission': 'mro',
#    'year': '2005',
#    'version': 'v08',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2005_v08.tm'},
#   {'mission': 'mro',
#    'year': '2006',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2006_v01.tm'},
#   {'mission': 'mro',
#    'year': '2006',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2006_v02.tm'},
#   {'mission': 'mro',
#    'year': '2006',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2006_v03.tm'},
#   {'mission': 'mro',
#    'year': '2006',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2006_v04.tm'},
#   {'mission': 'mro',
#    'year': '2006',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2006_v05.tm'},
#   {'mission': 'mro',
#    'year': '2006',
#    'version': 'v06',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2006_v06.tm'},
#   {'mission': 'mro',
#    'year': '2006',
#    'version': 'v07',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2006_v07.tm'},
#   {'mission': 'mro',
#    'year': '2006',
#    'version': 'v08',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2006_v08.tm'},
#   {'mission': 'mro',
#    'year': '2006',
#    'version': 'v09',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2006_v09.tm'},
#   {'mission': 'mro',
#    'year': '2006',
#    'version': 'v10',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2006_v10.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v01.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v02.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v03.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v04.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v05.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v06',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v06.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v07',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v07.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v08',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v08.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v09',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v09.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v10',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v10.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v11',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v11.tm'},
#   {'mission': 'mro',
#    'year': '2007',
#    'version': 'v12',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2007_v12.tm'},
#   {'mission': 'mro',
#    'year': '2008',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v01.tm'},
#   {'mission': 'mro',
#    'year': '2008',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v02.tm'},
#   {'mission': 'mro',
#    'year': '2008',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v03.tm'},
#   {'mission': 'mro',
#    'year': '2008',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v04.tm'},
#   {'mission': 'mro',
#    'year': '2008',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v05.tm'},
#   {'mission': 'mro',
#    'year': '2008',
#    'version': 'v06',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v06.tm'},
#   {'mission': 'mro',
#    'year': '2008',
#    'version': 'v07',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v07.tm'},
#   {'mission': 'mro',
#    'year': '2008',
#    'version': 'v08',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v08.tm'},
#   {'mission': 'mro',
#    'year': '2008',
#    'version': 'v09',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v09.tm'},
#   {'mission': 'mro',
#    'year': '2008',
#    'version': 'v10',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v10.tm'},
#   {'mission': 'mro',
#    'year': '2008',
#    'version': 'v11',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2008_v11.tm'},
#   {'mission': 'mro',
#    'year': '2009',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v01.tm'},
#   {'mission': 'mro',
#    'year': '2009',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v02.tm'},
#   {'mission': 'mro',
#    'year': '2009',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v03.tm'},
#   {'mission': 'mro',
#    'year': '2009',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v04.tm'},
#   {'mission': 'mro',
#    'year': '2009',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v05.tm'},
#   {'mission': 'mro',
#    'year': '2009',
#    'version': 'v06',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v06.tm'},
#   {'mission': 'mro',
#    'year': '2009',
#    'version': 'v07',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v07.tm'},
#   {'mission': 'mro',
#    'year': '2009',
#    'version': 'v08',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v08.tm'},
#   {'mission': 'mro',
#    'year': '2009',
#    'version': 'v09',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v09.tm'},
#   {'mission': 'mro',
#    'year': '2009',
#    'version': 'v10',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v10.tm'},
#   {'mission': 'mro',
#    'year': '2009',
#    'version': 'v11',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2009_v11.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v01.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v02.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v03.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v04.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v05.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v06',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v06.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v07',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v07.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v08',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v08.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v09',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v09.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v10',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v10.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v11',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v11.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v12',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v12.tm'},
#   {'mission': 'mro',
#    'year': '2010',
#    'version': 'v13',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2010_v13.tm'},
#   {'mission': 'mro',
#    'year': '2011',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2011_v01.tm'},
#   {'mission': 'mro',
#    'year': '2011',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2011_v02.tm'},
#   {'mission': 'mro',
#    'year': '2011',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2011_v03.tm'},
#   {'mission': 'mro',
#    'year': '2011',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2011_v04.tm'},
#   {'mission': 'mro',
#    'year': '2011',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2011_v05.tm'},
#   {'mission': 'mro',
#    'year': '2011',
#    'version': 'v06',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2011_v06.tm'},
#   {'mission': 'mro',
#    'year': '2011',
#    'version': 'v07',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2011_v07.tm'},
#   {'mission': 'mro',
#    'year': '2011',
#    'version': 'v08',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2011_v08.tm'},
#   {'mission': 'mro',
#    'year': '2011',
#    'version': 'v09',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2011_v09.tm'},
#   {'mission': 'mro',
#    'year': '2011',
#    'version': 'v10',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2011_v10.tm'},
#   {'mission': 'mro',
#    'year': '2012',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2012_v01.tm'},
#   {'mission': 'mro',
#    'year': '2012',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2012_v02.tm'},
#   {'mission': 'mro',
#    'year': '2012',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2012_v03.tm'},
#   {'mission': 'mro',
#    'year': '2012',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2012_v04.tm'},
#   {'mission': 'mro',
#    'year': '2012',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2012_v05.tm'},
#   {'mission': 'mro',
#    'year': '2012',
#    'version': 'v06',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2012_v06.tm'},
#   {'mission': 'mro',
#    'year': '2012',
#    'version': 'v07',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2012_v07.tm'},
#   {'mission': 'mro',
#    'year': '2012',
#    'version': 'v08',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2012_v08.tm'},
#   {'mission': 'mro',
#    'year': '2012',
#    'version': 'v09',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2012_v09.tm'},
#   {'mission': 'mro',
#    'year': '2013',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2013_v01.tm'},
#   {'mission': 'mro',
#    'year': '2013',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2013_v02.tm'},
#   {'mission': 'mro',
#    'year': '2013',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2013_v03.tm'},
#   {'mission': 'mro',
#    'year': '2013',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2013_v04.tm'},
#   {'mission': 'mro',
#    'year': '2013',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2013_v05.tm'},
#   {'mission': 'mro',
#    'year': '2013',
#    'version': 'v06',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2013_v06.tm'},
#   {'mission': 'mro',
#    'year': '2013',
#    'version': 'v07',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2013_v07.tm'},
#   {'mission': 'mro',
#    'year': '2013',
#    'version': 'v08',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2013_v08.tm'},
#   {'mission': 'mro',
#    'year': '2013',
#    'version': 'v09',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2013_v09.tm'},
#   {'mission': 'mro',
#    'year': '2014',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2014_v01.tm'},
#   {'mission': 'mro',
#    'year': '2014',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2014_v02.tm'},
#   {'mission': 'mro',
#    'year': '2014',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2014_v03.tm'},
#   {'mission': 'mro',
#    'year': '2014',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2014_v04.tm'},
#   {'mission': 'mro',
#    'year': '2014',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2014_v05.tm'},
#   {'mission': 'mro',
#    'year': '2014',
#    'version': 'v06',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2014_v06.tm'},
#   {'mission': 'mro',
#    'year': '2014',
#    'version': 'v07',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2014_v07.tm'},
#   {'mission': 'mro',
#    'year': '2015',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2015_v01.tm'},
#   {'mission': 'mro',
#    'year': '2015',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2015_v02.tm'},
#   {'mission': 'mro',
#    'year': '2015',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2015_v03.tm'},
#   {'mission': 'mro',
#    'year': '2015',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2015_v04.tm'},
#   {'mission': 'mro',
#    'year': '2015',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2015_v05.tm'},
#   {'mission': 'mro',
#    'year': '2016',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2016_v01.tm'},
#   {'mission': 'mro',
#    'year': '2016',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2016_v02.tm'},
#   {'mission': 'mro',
#    'year': '2016',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2016_v03.tm'},
#   {'mission': 'mro',
#    'year': '2016',
#    'version': 'v04',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2016_v04.tm'},
#   {'mission': 'mro',
#    'year': '2016',
#    'version': 'v05',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2016_v05.tm'},
#   {'mission': 'mro',
#    'year': '2017',
#    'version': 'v01',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2017_v01.tm'},
#   {'mission': 'mro',
#    'year': '2017',
#    'version': 'v02',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2017_v02.tm'},
#   {'mission': 'mro',
#    'year': '2017',
#    'version': 'v03',
#    'path': '/data/spice/mro-m-spice-6-v1.0/mrosp_1000/extras/mk/mro_2017_v03.tm'},
#   {'mission': 'apollo.sese.asu.edu',
#    'year': 'v01',
#    'version': '/data/spice/apollo.sese.asu.edu/EPHEMERIS/kernels/AS15/extras/mk/apollo15_v01.tm'}]}
