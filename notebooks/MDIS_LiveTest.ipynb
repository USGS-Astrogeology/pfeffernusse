# %%
import ctypes
import json

import requests
import csmapi

# %%
lib = '/home/jlaura/anaconda3/envs/ct/lib/libusgscsm.so'
ctypes.CDLL(lib)
# Out:
# <CDLL '/home/jlaura/anaconda3/envs/ct/lib/libusgscsm.so', handle 14f47f0 at 0x7fa428f7b400>

# %%
label = """
PDS_VERSION_ID       = PDS3                                                     
                                                                                
/*** FILE FORMAT ***/                                                           
RECORD_TYPE          = FIXED_LENGTH                                             
RECORD_BYTES         = 512                                                      
FILE_RECORDS          = 0526                                                    
LABEL_RECORDS         = 0014                                                    
                                                                                
/*** POINTERS TO START BYTE OFFSET OF OBJECTS IN IMAGE FILE ***/                
^IMAGE                = 0015                                                    
                                                                                
/*** GENERAL DATA DESCRIPTION PARAMETERS ***/                                   
MISSION_NAME         = "MESSENGER"                                              
INSTRUMENT_HOST_NAME = "MESSENGER"                                              
DATA_SET_ID          = "MESS-E/V/H-MDIS-2-EDR-RAWDATA-V1.0"                     
DATA_QUALITY_ID      = "0000000000000000"                                       
PRODUCT_ID           = "EN0221843562M"                                          
PRODUCT_VERSION_ID   = "3"                                                      
SOURCE_PRODUCT_ID    = ("0221843562_IM6WV")                                     
PRODUCER_INSTITUTION_NAME = "APPLIED COHERENT TECHNOLOGY CORPORATION"           
SOFTWARE_NAME        = "MDIS2EDR"                                               
SOFTWARE_VERSION_ID  = "1.0"                                                    
MISSION_PHASE_NAME   = "MERCURY ORBIT"                                          
TARGET_NAME          = "MERCURY"                                                
SEQUENCE_NAME        = "N/A"                                                    
OBSERVATION_ID       = "632379"                                                 
OBSERVATION_TYPE     = ("Monochrome","Targeted")                                
SITE_ID              = "2750"                                                   
                                                                                
/*** TIME PARAMETERS ***/                                                       
START_TIME           = 2011-08-14T21:08:15.524070                               
STOP_TIME            = 2011-08-14T21:08:15.532070                               
SPACECRAFT_CLOCK_START_COUNT = "1/0221843562:982000"                            
SPACECRAFT_CLOCK_STOP_COUNT = "1/0221843562:990000"                             
ORBIT_NUMBER         = 300                                                      
PRODUCT_CREATION_TIME = 2011-11-22T19:03:31                                     
                                                                                
/***  INSTRUMENT ENGINEERING PARAMETERS ***/                                    
INSTRUMENT_NAME      = "MERCURY DUAL IMAGING SYSTEM NARROW ANGLE CAMERA"        
INSTRUMENT_ID        = "MDIS-NAC"                                               
FILTER_NAME          = "748 BP 53"                                              
FILTER_NUMBER        = "N/A"                                                    
CENTER_FILTER_WAVELENGTH = 747.7 <NM>                                           
BANDWIDTH            = 52.6 <NM>                                                
EXPOSURE_DURATION    = 8 <MS>                                                   
EXPOSURE_TYPE        = AUTO                                                     
DETECTOR_TEMPERATURE = -44.19 <DEGC>                                            
FOCAL_PLANE_TEMPERATURE = -26.71 <DEGC>                                         
FILTER_TEMPERATURE   = "N/A"                                                    
OPTICS_TEMPERATURE   = -25.70 <DEGC>                                            
                                                                                
/*** INSTRUMENT RAW PARAMETERS ***/                                             
MESS:MET_EXP         = 221843562                                                
MESS:IMG_ID_LSB      = 42555                                                    
MESS:IMG_ID_MSB      = 9                                                        
MESS:ATT_CLOCK_COUNT = 221843560                                                
MESS:ATT_Q1          = -0.90050656                                              
MESS:ATT_Q2          = -0.33470878                                              
MESS:ATT_Q3          = -0.19896401                                              
MESS:ATT_Q4          = 0.19357501                                               
MESS:ATT_FLAG        = 7                                                        
MESS:PIV_POS_MOTOR   = 26781                                                    
MESS:PIV_GOAL        = "N/A"                                                    
MESS:PIV_POS         = 3265                                                     
MESS:PIV_READ        = 60080                                                    
MESS:PIV_CAL         = -26758                                                   
MESS:FW_GOAL         = 55684                                                    
MESS:FW_POS          = 55824                                                    
MESS:FW_READ         = 55824                                                    
MESS:CCD_TEMP        = 1020                                                     
MESS:CAM_T1          = 472                                                      
MESS:CAM_T2          = 502                                                      
MESS:EXPOSURE        = 8                                                        
MESS:DPU_ID          = 0                                                        
MESS:IMAGER          = 1                                                        
MESS:SOURCE          = 0                                                        
MESS:FPU_BIN         = 1                                                        
MESS:COMP12_8        = 1                                                        
MESS:COMP_ALG        = 1                                                        
MESS:COMP_FST        = 1                                                        
MESS:TIME_PLS        = 2                                                        
MESS:LATCH_UP        = 0                                                        
MESS:EXP_MODE        = 1                                                        
MESS:PIV_STAT        = 3                                                        
MESS:PIV_MPEN        = 0                                                        
MESS:PIV_PV          = 1                                                        
MESS:PIV_RV          = 1                                                        
MESS:FW_PV           = 1                                                        
MESS:FW_RV           = 1                                                        
MESS:AEX_STAT        = 640                                                      
MESS:AEX_STHR        = 5                                                        
MESS:AEX_TGTB        = 1830                                                     
MESS:AEX_BACB        = 240                                                      
MESS:AEX_MAXE        = 989                                                      
MESS:AEX_MINE        = 1                                                        
MESS:DLNKPRIO        = 6                                                        
MESS:WVLRATIO        = 4                                                        
MESS:PIXELBIN        = 0                                                        
MESS:SUBFRAME        = 0                                                        
MESS:SUBF_X1         = 0                                                        
MESS:SUBF_Y1         = 0                                                        
MESS:SUBF_DX1        = 0                                                        
MESS:SUBF_DY1        = 0                                                        
MESS:SUBF_X2         = 0                                                        
MESS:SUBF_Y2         = 0                                                        
MESS:SUBF_DX2        = 0                                                        
MESS:SUBF_DY2        = 0                                                        
MESS:SUBF_X3         = 0                                                        
MESS:SUBF_Y3         = 0                                                        
MESS:SUBF_DX3        = 0                                                        
MESS:SUBF_DY3        = 0                                                        
MESS:SUBF_X4         = 0                                                        
MESS:SUBF_Y4         = 0                                                        
MESS:SUBF_DX4        = 0                                                        
MESS:SUBF_DY4        = 0                                                        
MESS:SUBF_X5         = 0                                                        
MESS:SUBF_Y5         = 0                                                        
MESS:SUBF_DX5        = 0                                                        
MESS:SUBF_DY5        = 0                                                        
MESS:CRITOPNV        = 0                                                        
MESS:JAILBARS        = 0                                                        
MESS:JB_X0           = 0                                                        
MESS:JB_X1           = 0                                                        
MESS:JB_SPACE        = 0                                                        
                                                                                
/*** GEOMETRY INFORMATION ***/                                                  
RIGHT_ASCENSION      = 29.98095 <DEG>                                           
DECLINATION          = -60.31430 <DEG>                                          
TWIST_ANGLE          = 174.45073 <DEG>                                          
RA_DEC_REF_PIXEL     = (256.00000,256.00000)                                    
RETICLE_POINT_RA     = (31.58109 <DEG>,28.66723 <DEG>,31.36972 <DEG>,28.29792   
  <DEG>)                                                                        
RETICLE_POINT_DECLINATION = (-59.62863 <DEG>,-59.48869 <DEG>,-61.11649 <DEG>,   
  -60.96891 <DEG>)                                                              
                                                                                
/*** TARGET PARAMETERS ***/                                                     
SC_TARGET_POSITION_VECTOR = (-1015.40573 <KM>,-917.48842 <KM>,2425.50748 <KM>)  
TARGET_CENTER_DISTANCE = 2784.94530 <KM>                                        
                                                                                
/*** TARGET WITHIN SENSOR FOV ***/                                              
SLANT_DISTANCE       = 347.09879 <KM>                                           
CENTER_LATITUDE      = 63.12545 <DEG>                                           
CENTER_LONGITUDE     = 58.67519 <DEG>                                           
HORIZONTAL_PIXEL_SCALE = 17.69887 <M>                                           
VERTICAL_PIXEL_SCALE = 17.69887 <M>                                             
SMEAR_MAGNITUDE      = 3.12664 <PIXELS>                                         
SMEAR_AZIMUTH        = 315.85481 <DEG>                                          
NORTH_AZIMUTH        = 326.18001 <DEG>                                          
RETICLE_POINT_LATITUDE = (63.09619 <DEG>,63.27356 <DEG>,62.97828 <DEG>,         
  63.15593 <DEG>)                                                               
RETICLE_POINT_LONGITUDE = (58.34938 <DEG>,58.60877 <DEG>,58.73766 <DEG>,        
  59.00159 <DEG>)                                                               
                                                                                
/*** SPACECRAFT POSITION WITH RESPECT TO CENTRAL BODY ***/                      
SUB_SPACECRAFT_LATITUDE = 62.39897 <DEG>                                        
SUB_SPACECRAFT_LONGITUDE = 57.71721 <DEG>                                       
SPACECRAFT_ALTITUDE  = 344.94530 <KM>                                           
SUB_SPACECRAFT_AZIMUTH = 177.84843 <DEG>                                        
                                                                                
/*** SPACECRAFT LOCATION ***/                                                   
SPACECRAFT_SOLAR_DISTANCE = 62150890.26251 <KM>                                 
SC_SUN_POSITION_VECTOR = (44278649.20052 <KM>,-36396200.22193 <KM>,             
  -24030210.04496 <KM>)                                                         
SC_SUN_VELOCITY_VECTOR = (-20.66789 <KM/S>,-34.22486 <KM/S>,-14.94536 <KM/S>)   
                                                                                
/*** VIEWING AND LIGHTING GEOMETRY (SUN ON TARGET) ***/                         
SOLAR_DISTANCE       = 62152014.24323 <KM>                                      
SUB_SOLAR_AZIMUTH    = 179.47175 <DEG>                                          
SUB_SOLAR_LATITUDE   = -0.03317 <DEG>                                           
SUB_SOLAR_LONGITUDE  = 28.43827 <DEG>                                           
INCIDENCE_ANGLE      = 67.04617 <DEG>                                           
PHASE_ANGLE          = 60.22508 <DEG>                                           
EMISSION_ANGLE       = 6.82397 <DEG>                                            
LOCAL_HOUR_ANGLE     = 210.23691 <DEG>                                          
                                                                                
/*** GEOMETRY FOR EACH SUBFRAME ***/                                            
GROUP = SUBFRAME1_PARAMETERS                                                    
  RETICLE_POINT_LATITUDE = ("N/A","N/A","N/A","N/A")                            
  RETICLE_POINT_LONGITUDE = ("N/A","N/A","N/A","N/A")                           
END_GROUP = SUBFRAME1_PARAMETERS                                                
                                                                                
GROUP = SUBFRAME2_PARAMETERS                                                    
  RETICLE_POINT_LATITUDE = ("N/A","N/A","N/A","N/A")                            
  RETICLE_POINT_LONGITUDE = ("N/A","N/A","N/A","N/A")                           
END_GROUP = SUBFRAME2_PARAMETERS                                                
                                                                                
GROUP = SUBFRAME3_PARAMETERS                                                    
  RETICLE_POINT_LATITUDE = ("N/A","N/A","N/A","N/A")                            
  RETICLE_POINT_LONGITUDE = ("N/A","N/A","N/A","N/A")                           
END_GROUP = SUBFRAME3_PARAMETERS                                                
                                                                                
GROUP = SUBFRAME4_PARAMETERS                                                    
  RETICLE_POINT_LATITUDE = ("N/A","N/A","N/A","N/A")                            
  RETICLE_POINT_LONGITUDE = ("N/A","N/A","N/A","N/A")                           
END_GROUP = SUBFRAME4_PARAMETERS                                                
                                                                                
GROUP = SUBFRAME5_PARAMETERS                                                    
  RETICLE_POINT_LATITUDE = ("N/A","N/A","N/A","N/A")                            
  RETICLE_POINT_LONGITUDE = ("N/A","N/A","N/A","N/A")                           
END_GROUP = SUBFRAME5_PARAMETERS                                                
                                                                                
                                                                                
OBJECT = IMAGE                                                                  
  LINES              = 512                                                      
  LINE_SAMPLES       = 512                                                      
  SAMPLE_TYPE        = UNSIGNED_INTEGER                                         
  SAMPLE_BITS        = 8                                                        
  UNIT               = "N/A"                                                    
  DARK_STRIP_MEAN    = 30.643                                                   
                                                                                
/*** IMAGE STATISTICS OF  ***/                                                  
/*** THE EXPOSED CCD AREA ***/                                                  
  MINIMUM            = 28.000                                                   
  MAXIMUM            = 173.000                                                  
  MEAN               = 130.664                                                  
  STANDARD_DEVIATION = 9.641                                                    
                                                                                
/*** PIXEL COUNTS ***/                                                          
  SATURATED_PIXEL_COUNT = 0                                                     
  MISSING_PIXELS     = 0                                                        
END_OBJECT = IMAGE                                                              
END         
"""

# %%
resp = requests.post('http://smalls:58080/v1/pds/', json={"label":label})
with open('/home/jlaura/Downloads/EN0221843562M2.json', 'w') as f:
    json.dump(resp.json(), f)

# %%
plugin = csmapi.Plugin.findPlugin('UsgsAstroPluginCSM')
isd = csmapi.Isd('/home/jlaura/Downloads/EN0221843562M2.json')
model_name = resp.json()['name_model']

# %%
if plugin.canModelBeConstructedFromISD(isd, model_name):
    model = plugin.constructModelFromISD(isd, model_name)

# %%
isize = model.getImageSize()
isize.line, isize.samp
# Out:
# (512.0, 512.0)

# %%
ic = csmapi.ImageCoord(206, 206)
gnd = model.imageToGround(ic, 0)
gnd.x, gnd.y, gnd.z
# Out:
# (479190.5743225043, 1379557.7476122049, 1953936.8399422762)

# %%
resp.json()
# Out:
# {'center_ephemeris_time': 366628163.75502384,
#  'detector_center': {'line': 512.5, 'sample': 512.5},
#  'detector_line_summing': 1.0,
#  'detector_sample_summing': 1.0,
#  'focal2pixel_lines': [0.0, 0.0, 71.42857143],
#  'focal2pixel_samples': [0.0, 71.42857143, 0.0],
#  'focal_length_model': {'focal_epsilon': 0.5,
#   'focal_length': 549.2399911991896},
#  'image_lines': 512.0,
#  'image_samples': 512.0,
#  'interpolation_method': 'lagrange',
#  'name_model': 'USGS_ASTRO_FRAME_SENSOR_MODEL',
#  'name_platform': 'MESSENGER',
#  'name_sensor': 'MSGR_MDIS_NAC',
#  'optical_distortion': {'transverse': {'x': [0.0,
#     1.001854269623802,
#     0.0,
#     0.0,
#     -0.0005094440474941111,
#     0.0,
#     1.004010471468856e-05,
#     0.0,
#     1.004010471468856e-05,
#     0.0],
#    'y': [0.0,
#     0.0,
#     1.0,
#     0.0009060010594996751,
#     0.0,
#     0.0003574842626620758,
#     0.0,
#     1.004010471468856e-05,
#     0.0,
#     1.004010471468856e-05]}},
# ...
